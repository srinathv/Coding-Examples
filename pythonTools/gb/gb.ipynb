# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import datetime
import csv
import matplotlib.cbook as cbook

# %%
#fname = cbook.get_sample_data('/Users/srinathv/Downloads/MyExportedGlucoseBuddyLogs.csv', asfileobj=False)
#print fname
#plt.plotfile(fname,(0,1))
#plt.show()

# %%
bgValues=[]; bgDatesTimes=[];
medType=[];medValue=[];medDatesTimes=[];
f=open('/Users/srinathv/Downloads/MyExportedGlucoseBuddyLogs.csv')
for row in csv.reader(f):
    if 'BG' in row[0]:
      bgValues.append(row[1])
      bgDatesTimes.append(row[5])
    if 'M' in row[0]:
      medType.append(row[3])
      medValue.append(row[1])
      medDatesTimes.append(row[5])

# %%
fig1=plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
ax = fig1.add_subplot(1,1,1,)
#ax2 = fig1.add_subplot(1,1,1,)
#n,bins,patches=ax2.hist(orgarray[1:],bins=50,label=orgLabel)\n",
ax.plot(range(0,len(bgValues)),bgValues,'o--')
plt.xticks(range(0,len(bgValues)), bgDatesTimes,rotation=90)
plt.xlabel("date, time")
plt.ylabel("BG ")
plotTitle = "Srinath V BG over last 30days" 
plt.title(plotTitle)
#plt.legend()
plt.show()

# %%
glybUnit=1.25
metUnit=500
for pill in medType:
  if 'glyb' in pill:
        print pill
print len(medType)
print len(medValue)
# Out:
# glyburide
# glyburide
# glyburide
# glyburide
# glyburide
# glyburide
# glyburide
# glyburide
# glyburide
# glyburide
# glyburide
# glyburide
# glyburide
# glyburide
# glyburide
# glyburide
# glyburide
# 31
# 31
